# %%
# 1.Import Required libraries

import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
import warnings
warnings.filterwarnings("ignore")

# %%
# 2.Import the dataset

link = "I:\Datasets\laptopData.csv"

# %%
# 3.Load the Dataset into pandas dataframe.  

df = pd.read_csv(link)
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
# 4.Data Preprocessing

df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
# Replace missing values in numerical columns with their mean
df.fillna(df.select_dtypes(include=['float64']).mean(), inplace=True)

# Replace missing values in categorical columns with their mode (most frequent value)
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify if all missing values are handled
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#Statistical Summary

df.describe()
# Out:
#         Unnamed: 0          Price
# count  1303.000000    1303.000000
# mean    652.674784   59955.814073
# std     372.130272   36899.649480
# min       0.000000    9270.720000
# 25%     334.500000   32650.250400
# 50%     652.674784   52747.200000
# 75%     971.500000   78561.360000
# max    1302.000000  324954.720000

# %%
# Get basic statistics of categorical columns
df.describe(include=['O']) ## 'O' means object type (categorical data)
# Out:
#        Company  TypeName Inches   ScreenResolution  \
# count     1303      1303   1303               1303
# unique      19         6     25                 40
# top     Lenovo  Notebook   15.6  Full HD 1920x1080
# freq       320       740    670                525
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118    10         40                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           213   631        431                    301
#
#              OpSys Weight
# count         1303   1303
# unique           9    189
# top     Windows 10  2.2kg
# freq          1077    141

# %%
# 5.Data Formatting & Normalization

# Check data types of all columns
print("\nData types of each column:")
print(df.dtypes)

# Convert data types if needed (Example: Convert Price column to float)
df['Price'] = df['Price'].astype(float)  # Uncomment if needed

# Check again after conversion
print("\nUpdated data types:")
df.dtypes
# Out:
# Data types of each column:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object
#
# Updated data types:
# Unnamed: 0          float64
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
# Convert Categorical Variables into Quantitative Variables

from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
print("Categorical Columns:", categorical_columns)

# Apply Label Encoding to each categorical column
encoder = LabelEncoder()
for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

# Display the updated DataFrame
df.head()
# Out:
# Categorical Columns: Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight'],
#       dtype='object')
#    Unnamed: 0  Company  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0         0.0        1         4       7                23   65    9       4
# 1         1.0        1         4       7                 1   63    9       2
# 2         2.0        7         3      14                 8   74    9      16
# 3         3.0        1         4      13                25   85    1      29
# 4         4.0        1         4       7                23   67    9      16
#
#    Gpu  OpSys  Weight        Price
# 0   58      8      39   71378.6832
# 1   51      8      36   47895.5232
# 2   53      4      75   30636.0000
# 3    9      8      72  135195.3360
# 4   59      8      39   96095.8080
